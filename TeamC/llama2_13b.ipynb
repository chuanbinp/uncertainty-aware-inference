# %%
# !git clone https://github.com/chuanbinp/uncertainty-aware-inference.git
# Out:
# Cloning into 'uncertainty-aware-inference'...
# remote: Enumerating objects: 1941, done.
# remote: Counting objects: 100% (222/222), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 1941 (delta 123), reused 124 (delta 120), pack-reused 1719 (from 2)
# Receiving objects: 100% (1941/1941), 114.60 MiB | 1.73 MiB/s, done.
# Resolving deltas: 100% (650/650), done.

# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")
# Out:
# PyTorch version: 2.10.0+cu128
# CUDA available: True
# CUDA version: 12.8

# %%
# !pip install numpy plotly matplotlib torch transformers datasets accelerate gptqmodel netcal autoawq bitsandbytes wandb

# %%
cd uncertainty-aware-inference/TeamC
# Out:
# [Errno 2] No such file or directory: 'uncertainty-aware-inference/TeamC'
# /content/uncertainty-aware-inference/TeamC/uncertainty-aware-inference/TeamC

# %%
from huggingface_hub import login
from google.colab import userdata, files

login(token=userdata.get('HF_TOKEN'))

# %%
import wandb
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: sl5806 (sl5806-columbia-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ## llama2-13b-fp16

# %%
config_key_new_value = "llama2-13b-fp16"
# !sed -i 's/^CONFIG_KEY = \".*\"/CONFIG_KEY = \"'$config_key_new_value'\"/' run_eval.py
# Verify the change by printing the first few lines of the file
# !head -n 200 run_eval.py
# Out:
# # Team C — Calibration Evaluation
# # Runs one quantization config across hellaswag, triviaqa, pubmedqa.
# #
# # Configs (see TeamA/configs.py):
# #   llama2-13b-fp16       FP16 baseline     needs HF_TOKEN
# #   llama2-13b-nf4        NF4 bitsandbytes  needs HF_TOKEN
# #   llama2-13b-awq-int4   AWQ INT4          no token needed
# #   llama2-13b-gptq-int4  GPTQ INT4         no token needed
# #   llama2-13b-gptq-int8  GPTQ INT8         no token needed
# #
# # Usage:
# #   python TeamC/run_eval.py
# #   HF_TOKEN=hf_... python TeamC/run_eval.py   # for gated models
#
#
# import os
# import sys
#
# sys.path.insert(0, os.path.dirname(os.path.dirname(os.path.abspath(__file__))))
#
# from TeamC.configs import MODEL_REGISTRY
# from shared.model_loader import load_model, free_model
# from shared.eval_utils import run_eval
# import wandb
#
# CONFIG_KEY = "llama2-13b-fp16"
# MAX_SAMPLES = None
# SEED = 42
#
# OUTPUT_DIR = f"./full_results/{CONFIG_KEY}"
#
# run = wandb.init(
# ...

# %%
# %run run_eval.py
# Out:
# /usr/local/lib/python3.12/dist-packages/awq/__init__.py:21: DeprecationWarning:
# I have left this message as the final dev message to help you transition.
#
# Important Notice:
# - AutoAWQ is officially deprecated and will no longer be maintained.
# - The last tested configuration used Torch 2.6.0 and Transformers 4.51.3.
# - If future versions of Transformers break AutoAWQ compatibility, please report the issue to the Transformers project.
#
# Alternative:
# - AutoAWQ has been adopted by the vLLM Project: https://github.com/vllm-project/llm-compressor
#
# For further inquiries, feel free to reach out:
# - X: https://x.com/casper_hansen_
# - LinkedIn: https://www.linkedin.com/in/casper-hansen-804005170/
#
#   warnings.warn(_FINAL_DEV_MESSAGE, category=DeprecationWarning, stacklevel=1)
# WARNING:torchao:Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# ...

# %%
# !rm /content/llama2-13b-fp16.zip
# !cd /content/uncertainty-aware-inference/TeamC/updated_results/llama2-13b-fp16 && zip -r /content/llama2-13b-fp16.zip .
# !cd /content/uncertainty-aware-inference/TeamC
# Out:
# rm: cannot remove '/content/llama2-13b-fp16.zip': No such file or directory
#   adding: llama2-13b_16bit_fp16_pubmedqa_reliability.png (deflated 9%)
#   adding: llama2-13b_16bit_fp16_triviaqa_entropy.png (deflated 15%)
#   adding: llama2-13b_16bit_fp16_pubmedqa.pt (deflated 43%)
#   adding: llama2-13b_16bit_fp16_hellaswag_entropy.png (deflated 14%)
#   adding: llama2-13b_16bit_fp16_hellaswag.json (deflated 31%)
#   adding: llama2-13b_16bit_fp16_hellaswag_reliability.png (deflated 6%)
#   adding: llama2-13b_16bit_fp16_pubmedqa.json (deflated 32%)
#   adding: llama2-13b_16bit_fp16_pubmedqa_entropy.png (deflated 14%)
#   adding: llama2-13b_16bit_fp16_triviaqa.pt (deflated 43%)
#   adding: llama2-13b_16bit_fp16_triviaqa.json (deflated 31%)
#   adding: llama2-13b_16bit_fp16_hellaswag.pt (deflated 43%)
#   adding: llama2-13b_16bit_fp16_triviaqa_reliability.png (deflated 7%)

# %%
files.download("/content/llama2-13b-fp16.zip")

# %% [markdown]
# ## AWQ

# %%
config_key_new_value = "llama2-13b-awq-int4"
# !sed -i 's/^CONFIG_KEY = \".*\"/CONFIG_KEY = \"'$config_key_new_value'\"/' run_eval.py
# Verify the change by printing the first few lines of the file
# !head -n 200 run_eval.py
# Out:
# # Team C — Calibration Evaluation
# # Runs one quantization config across hellaswag, triviaqa, pubmedqa.
# #
# # Configs (see TeamA/configs.py):
# #   llama2-13b-fp16       FP16 baseline     needs HF_TOKEN
# #   llama2-13b-nf4        NF4 bitsandbytes  needs HF_TOKEN
# #   llama2-13b-awq-int4   AWQ INT4          no token needed
# #   llama2-13b-gptq-int4  GPTQ INT4         no token needed
# #   llama2-13b-gptq-int8  GPTQ INT8         no token needed
# #
# # Usage:
# #   python TeamC/run_eval.py
# #   HF_TOKEN=hf_... python TeamC/run_eval.py   # for gated models
#
#
# import os
# import sys
#
# sys.path.insert(0, os.path.dirname(os.path.dirname(os.path.abspath(__file__))))
#
# from TeamC.configs import MODEL_REGISTRY
# from shared.model_loader import load_model, free_model
# from shared.eval_utils import run_eval
# import wandb
#
# CONFIG_KEY = "llama2-13b-awq-int4"
# MAX_SAMPLES = None
# SEED = 42
#
# OUTPUT_DIR = f"./full_results/{CONFIG_KEY}"
#
# run = wandb.init(
# ...

# %%
# %run run_eval.py
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/wandb/analytics/sentry.py:268: DeprecationWarning: Read the `app_url` setting from the appropriate Settings object.
#   app_url = wandb.util.app_url(tags["base_url"])  # type: ignore[index]
# /usr/local/lib/python3.12/dist-packages/wandb/analytics/sentry.py:279: DeprecationWarning: The `Scope.user` setter is deprecated in favor of `Scope.set_user()`.
#   self.scope.user = {"email": email}
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/uncertainty-aware-inference/TeamC/uncertainty-aware-inference/TeamC/wandb/run-20260504_021333-erq2zyrj</code>
# ...

# %%
# !rm /content/llama2-13b-awq-int4.zip
# !cd /content/uncertainty-aware-inference/TeamC/updated_results/llama2-13b-awq-int4 && zip -r /content/llama2-13b-awq-int4.zip .
# !cd /content/uncertainty-aware-inference/TeamC
# Out:
# rm: cannot remove '/content/llama2-13b-awq-int4.zip': No such file or directory
#   adding: llama2-13b_4bit_awq_hellaswag_entropy.png (deflated 13%)
#   adding: llama2-13b_4bit_awq_triviaqa.json (deflated 31%)
#   adding: llama2-13b_4bit_awq_triviaqa_entropy.png (deflated 15%)
#   adding: llama2-13b_4bit_awq_hellaswag_reliability.png (deflated 7%)
#   adding: llama2-13b_4bit_awq_pubmedqa.json (deflated 32%)
#   adding: llama2-13b_4bit_awq_pubmedqa_reliability.png (deflated 9%)
#   adding: llama2-13b_4bit_awq_triviaqa.pt (deflated 42%)
#   adding: llama2-13b_4bit_awq_hellaswag.json (deflated 31%)
#   adding: llama2-13b_4bit_awq_pubmedqa_entropy.png (deflated 14%)
#   adding: llama2-13b_4bit_awq_triviaqa_reliability.png (deflated 7%)
#   adding: llama2-13b_4bit_awq_pubmedqa.pt (deflated 43%)
#   adding: llama2-13b_4bit_awq_hellaswag.pt (deflated 43%)

# %%
files.download("/content/llama2-13b-awq-int4.zip")

# %% [markdown]
# ## NF4

# %%
config_key_new_value = "llama2-13b-nf4"
# !sed -i 's/^CONFIG_KEY = \".*\"/CONFIG_KEY = \"'$config_key_new_value'\"/' run_eval.py
# Verify the change by printing the first few lines of the file
# !head -n 200 run_eval.py
# Out:
# # Team C — Calibration Evaluation
# # Runs one quantization config across hellaswag, triviaqa, pubmedqa.
# #
# # Configs (see TeamA/configs.py):
# #   llama2-13b-fp16       FP16 baseline     needs HF_TOKEN
# #   llama2-13b-nf4        NF4 bitsandbytes  needs HF_TOKEN
# #   llama2-13b-awq-int4   AWQ INT4          no token needed
# #   llama2-13b-gptq-int4  GPTQ INT4         no token needed
# #   llama2-13b-gptq-int8  GPTQ INT8         no token needed
# #
# # Usage:
# #   python TeamC/run_eval.py
# #   HF_TOKEN=hf_... python TeamC/run_eval.py   # for gated models
#
#
# import os
# import sys
#
# sys.path.insert(0, os.path.dirname(os.path.dirname(os.path.abspath(__file__))))
#
# from TeamC.configs import MODEL_REGISTRY
# from shared.model_loader import load_model, free_model
# from shared.eval_utils import run_eval
# import wandb
#
# CONFIG_KEY = "llama2-13b-nf4"
# MAX_SAMPLES = None
# SEED = 42
#
# OUTPUT_DIR = f"./full_results/{CONFIG_KEY}"
#
# run = wandb.init(
# ...

# %%
# %run run_eval.py
# Out:
# /usr/local/lib/python3.12/dist-packages/wandb/analytics/sentry.py:268: DeprecationWarning: Read the `app_url` setting from the appropriate Settings object.
#   app_url = wandb.util.app_url(tags["base_url"])  # type: ignore[index]
# /usr/local/lib/python3.12/dist-packages/wandb/analytics/sentry.py:279: DeprecationWarning: The `Scope.user` setter is deprecated in favor of `Scope.set_user()`.
#   self.scope.user = {"email": email}
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/wandb/analytics/sentry.py:268: DeprecationWarning: Read the `app_url` setting from the appropriate Settings object.
#   app_url = wandb.util.app_url(tags["base_url"])  # type: ignore[index]
# ...
